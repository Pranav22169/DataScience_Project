# %%
#Part 1.1(Sentiment Analysis, NLP, and Knowledge Graph Construction) for Ola dataset
import pandas as pd
import spacy
import collections
import networkx as nx
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# Load spaCy model for tokenization
nlp = spacy.load("en_core_web_sm")  # Load the English model

# Load the CSV file
csv_file = r"C:\Users\prabi\OneDrive\Desktop\V sem\FDS_project\Datasets\Ola.xlsx"
df = pd.read_excel(csv_file)

# Step 0: Sentiment distribution pie chart
# Assuming the column with sentiment classification is named 'Outcome' with values 'positive', 'negative', 'neutral'
sentiment_counts = df['Outcome'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Sentiment Distribution')
plt.show()

# Combine all comments into a single string
text_data = ' '.join(df['Comment'].astype(str).tolist())  # Assuming the column is named 'comments'

# Step 1: Eliminate stop words and get word counts
stop_words = set(stopwords.words('english'))
doc = nlp(text_data)  # Process the text with spaCy
filtered_words = [token.text.lower() for token in doc if token.is_alpha and token.text.lower() not in stop_words]

# Count the top 10 words
word_counts = collections.Counter(filtered_words)
top_10_words = word_counts.most_common(10)
print("Top 10 words:")
for word, count in top_10_words:
    print(f"{word}: {count}")

# Step 2: Named Entity Recognition (NER)
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")

# Step 3: Derive Knowledge Graph with only 25 nodes
edges = []
for ent in doc.ents:
    edges.append((ent.text, ent.label_))

# Reduce the number of edges to 25
edges = edges[:25]

# Create a graph from the edges
graph = nx.Graph()
graph.add_edges_from(edges)

# Step 4: Draw the knowledge graph with node size set to 500
plt.figure(figsize=(10, 6))
nx.draw(graph, with_labels=True, node_color='skyblue', node_size=500,  # Set node size to 500
        font_size=10, font_color='black')
plt.title('Knowledge Graph (Reduced to 25 Entities)')
plt.show()

# Code for Wordcloud
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()
# Out:
# Top 10 words:
# ola: 401
# service: 164
# worst: 132
# driver: 121
# ride: 94
# cab: 84
# bad: 74
# experience: 73
# customer: 71
# drivers: 67
#
# Named Entities:
# OLA - ORG
# today - DATE
# Ola - PERSON
# Ola - PERSON
# Cheetar Ola - Looting - ORG
# Third - ORDINAL
# BAD Cheats - ORG
# Ola - PERSON
# Wrost - ORG
# Ola - PERSON
# Ola - PERSON
# Cheetar Ola - Looting - ORG
# Third - ORDINAL
# BAD Cheats - ORG
# Ola - PERSON
# Wrost - ORG
# Ola Bike - ORG
# Fraud - GPE
# Yesterday - DATE
# Ola - PERSON
# Ola - PERSON
# Ola - PERSON
# Need - ORG
# Today - DATE
# Ola - PERSON
# Ola - PERSON
# Worst - ORG
# Cab - PERSON
# Faulty - PERSON
# Driver - PERSON
# Thrid - GPE
# Driver - PERSON
# Ola - ORG
# Ola - PERSON
# Driver - PERSON
# Disappointed Customer Care Service Ola - ORG
# Ola - PERSON
# years - DATE
# KA 09 D 5899 - LAW
# 15 - CARDINAL
# Ola - PERSON
# Ola - PERSON
# Worst - NORP
# Ola Air - ORG
# 1 - CARDINAL
# Dinesh Pathetic - ORG
# Humne Compney k Name - ORG
# Kiya - PERSON
# ...

# %%
#Part 1.1(Sentiment Analysis, NLP, and Knowledge Graph Construction) for Uber dataset
import pandas as pd
import spacy
import collections
import networkx as nx
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# Load spaCy model for tokenization
nlp = spacy.load("en_core_web_sm")  # Load the English model

# Load the CSV file
csv_file = r"C:\Users\prabi\OneDrive\Desktop\V sem\FDS_project\Datasets\Uber.xlsx"
df = pd.read_excel(csv_file)

# Step 0: Sentiment distribution pie chart
# Assuming the column with sentiment classification is named 'Outcome' with values 'positive', 'negative', 'neutral'
sentiment_counts = df['Outcome'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Sentiment Distribution')
plt.show()

# Combine all comments into a single string
text_data = ' '.join(df['Comment'].astype(str).tolist())  # Assuming the column is named 'comments'

# Step 1: Eliminate stop words and get word counts
stop_words = set(stopwords.words('english'))
doc = nlp(text_data)  # Process the text with spaCy
filtered_words = [token.text.lower() for token in doc if token.is_alpha and token.text.lower() not in stop_words]

# Count the top 10 words
word_counts = collections.Counter(filtered_words)
top_10_words = word_counts.most_common(10)
print("Top 10 words:")
for word, count in top_10_words:
    print(f"{word}: {count}")

# Step 2: Named Entity Recognition (NER)
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")

# Step 3: Derive Knowledge Graph with only 25 nodes
edges = []
for ent in doc.ents:
    edges.append((ent.text, ent.label_))

# Reduce the number of edges to 25
edges = edges[:25]

# Create a graph from the edges
graph = nx.Graph()
graph.add_edges_from(edges)

# Step 4: Draw the knowledge graph with node size set to 500
plt.figure(figsize=(10, 6))
nx.draw(graph, with_labels=True, node_color='skyblue', node_size=500,  # Set node size to 500
        font_size=10, font_color='black')
plt.title('Knowledge Graph (Reduced to 25 Entities)')
plt.show()

# Code for Wordcloud
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()
# Out:
# Top 10 words:
# uber: 508
# driver: 212
# service: 148
# customer: 107
# drivers: 107
# app: 85
# use: 85
# ride: 80
# get: 78
# company: 76
#
# Named Entities:
# Uber/Uber Eats - ORG
# Impossible - ORG
# four - CARDINAL
# Rider - ORG
# two - CARDINAL
# Bloody - PERSON
# Left - PRODUCT
# Taxi - PERSON
# 30 minutes - TIME
# Fare - ORG
# 2022 - DATE
# One - CARDINAL
# Drivers - FAC
# first - ORDINAL
# UK - GPE
# 20 minutes - TIME
# Rubbish Poor - PERSON
# Rip off Awful service - ORG
# Fraud - PERSON
# Ripped - PERSON
# NEVER NEVER - NORP
# Worst - ORG
# July 6ht 2024 - DATE
# 5Pm - CARDINAL
# 0 - CARDINAL
# 5 - CARDINAL
# Scams - ORG
# 1hours - CARDINAL
# years - DATE
# One - CARDINAL
# Driver - PERSON
# Impolite - NORP
# Hopeless - NORP
# DRIVER EMILIANO 110 - PERSON
# A/C. Refuses - ORG
# Driver - ORG
# Review for Uber Service Terrible - ORG
# EN70DKU hyundia - PERSON
# Newcastle Please - ORG
# Loyal - ORG
# rome - GPE
# Items - NORP
# Modern Slavery Complete - ORG
# Items - NORP
# ...

# %%
#Part 1.1(Sentiment Analysis, NLP, and Knowledge Graph Construction) for Rapido  dataset
import pandas as pd
import spacy
import collections
import networkx as nx
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# Load spaCy model for tokenization
nlp = spacy.load("en_core_web_sm")  # Load the English model

# Load the CSV file
csv_file = r"C:\Users\prabi\OneDrive\Desktop\V sem\FDS_project\Datasets\Rapido1.xlsx"
df = pd.read_excel(csv_file)

# Step 0: Sentiment distribution pie chart
# Assuming the column with sentiment classification is named 'Outcome' with values 'positive', 'negative', 'neutral'
sentiment_counts = df['Outcome'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightgreen', 'lightcoral', 'lightskyblue'])
plt.title('Sentiment Distribution')
plt.show()

# Combine all comments into a single string
text_data = ' '.join(df['Comment'].astype(str).tolist())  # Assuming the column is named 'comments'

# Step 1: Eliminate stop words and get word counts
stop_words = set(stopwords.words('english'))
doc = nlp(text_data)  # Process the text with spaCy
filtered_words = [token.text.lower() for token in doc if token.is_alpha and token.text.lower() not in stop_words]

# Count the top 10 words
word_counts = collections.Counter(filtered_words)
top_10_words = word_counts.most_common(10)
print("Top 10 words:")
for word, count in top_10_words:
    print(f"{word}: {count}")

# Step 2: Named Entity Recognition (NER)
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")

# Step 3: Derive Knowledge Graph with only 25 nodes
edges = []
for ent in doc.ents:
    edges.append((ent.text, ent.label_))

# Reduce the number of edges to 25
edges = edges[:25]

# Create a graph from the edges
graph = nx.Graph()
graph.add_edges_from(edges)

# Step 4: Draw the knowledge graph with node size set to 500
plt.figure(figsize=(10, 6))
nx.draw(graph, with_labels=True, node_color='skyblue', node_size=500,  # Set node size to 500
        font_size=10, font_color='black')
plt.title('Knowledge Graph (Reduced to 25 Entities)')
plt.show()

# Code for Wordcloud
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()
# Out:
# Top 10 words:
# rapido: 295
# app: 277
# ride: 228
# service: 155
# driver: 143
# worst: 131
# time: 126
# drivers: 111
# customer: 102
# auto: 100
#
# Named Entities:
# Rapido - ORG
# Rapido - ORG
# Rapido - ORG
# Rapido Wallet - ORG
# Rapido - GPE
# as much as 50rs - PERCENT
# 10 minutes - TIME
# 3 years - DATE
# Worst - ORG
# daily - DATE
# Rapido - ORG
# 5 minutes - TIME
# cabs+autos - ORG
# Rapido - ORG
# Rapido - ORG
# last 8 - DATE
# Rapido - ORG
# 1 - MONEY
# about 20 seconds - TIME
# 3 seconds - TIME
# the past month - DATE
# around ₹200 - MONEY
# First - ORDINAL
# first - ORDINAL
# second - ORDINAL
# 44 - MONEY
# 47 52, 57 and - DATE
# ₹64 - MONEY
# Rapido - ORG
# 3 - CARDINAL
# 8 - CARDINAL
# 15-20 - CARDINAL
# only 3 - CARDINAL
# rapido - ORG
# daily - DATE
# two - CARDINAL
# un - ORG
# Application - ORG
# Morning - TIME
# UPI - ORG
# UPI - NORP
# Chennai - ORG
# more than 20 - CARDINAL
# First - ORDINAL
# last minute - TIME
# wel Very - PERSON
# more than a year - DATE
# ...

# %%
#part 1.1(NLP Analysis of Recommendation Feedback and Knowledge Graph Construction) for special Dataset
import pandas as pd
import spacy
import collections
import networkx as nx
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# Load spaCy model for tokenization
nlp = spacy.load("en_core_web_sm")  # Load the English model

# Load the CSV file
csv_file = r"C:\Users\prabi\OneDrive\Desktop\V sem\FDS_project\Datasets\Special.xlsx"
df = pd.read_excel(csv_file)

# Combine all comments into a single string
text_data = ' '.join(df['Please explain why you would recommend it?'].astype(str).tolist())  # Assuming the column is named 'comments'

# Step 1: Eliminate stop words and get word counts
stop_words = set(stopwords.words('english'))
doc = nlp(text_data)  # Process the text with spaCy
filtered_words = [token.text.lower() for token in doc if token.is_alpha and token.text.lower() not in stop_words]

# Count the top 10 words
word_counts = collections.Counter(filtered_words)
top_10_words = word_counts.most_common(10)
print("Top 10 words:")
for word, count in top_10_words:
    print(f"{word}: {count}")

# Step 2: Named Entity Recognition (NER)
print("\nNamed Entities:")
for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")

# Step 3: Derive Knowledge Graph with only 25 nodes
edges = []
for ent in doc.ents:
    edges.append((ent.text, ent.label_))

# Reduce the number of edges to 25
edges = edges[:25]

# Create a graph from the edges
graph = nx.Graph()
graph.add_edges_from(edges)

# Step 4: Draw the knowledge graph with node size set to 500
plt.figure(figsize=(10, 6))
nx.draw(graph, with_labels=True, node_color='skyblue', node_size=500,  # Set node size to 500
        font_size=10, font_color='black')
plt.title('Knowledge Graph (Reduced to 25 Entities)')
plt.show()

# Code for Wordcloud
from wordcloud import WordCloud

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400,
                      background_color='white').generate(text_data)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud')
plt.show()
# Out:
# Top 10 words:
# travel: 15
# time: 14
# easy: 10
# drivers: 9
# even: 9
# would: 8
# apps: 8
# good: 7
# one: 7
# service: 7
#
# Named Entities:
# Convenience - ORG
# Cause - ORG
# Rapido - ORG
# Reliable - PERSON
# Useful Easy - GPE
# Comfortable - WORK_OF_ART
# আমি - PERSON
# এবং আমি আমার সমস্ত বন্ধুদের - PERSON
# Easy - PERSON
# Easy - PERSON
# Time - ORG
# l. Convince - PERSON
# Helpful - GPE
# Easily - ORG
# Booking - ORG
# 3 in the morning - TIME
# Tells - PERSON
# Cab - PERSON
# one day - DATE
# 3 am - TIME
# Driver - PERSON
# Rapido - ORG
# one - CARDINAL
# 12:23 am - TIME
# Sarjapur Thw - FAC
# Driver - PERSON
# Whitefield - GPE
# Travel - ORG
# 12 in the night - TIME
# 2 years - DATE
# Sarjapur - PERSON
# one day - DATE
# ac  Good - ORG
# one - CARDINAL
# Works - PERSON
# Yelahanka - GPE
# C:\Users\prabi\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2438 (\N{BENGALI LETTER AA}) missing from current font.
# ...
